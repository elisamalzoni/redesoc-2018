# %% [markdown]
# # Balanceamento Estrutural
#
# Importando bibliotecas:

# %%
import networkx as nx
import socnet as sn

from random import choice, random
from itertools import combinations
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Configurando bibliotecas:

# %%
sn.node_size = 5
sn.node_color = (255, 255, 255)

sn.edge_width = 1

# %% [markdown]
# Definindo constantes:

# %%
NUM_NODES = 15

POSITIVE_COLOR = (0, 0, 255)
NEGATIVE_COLOR = (255, 0, 0)

# %% [markdown]
# Inicialização da simulação:

# %%
def set_edge_color(g, n, m):
    if g.edges[n, m]['signal'] == 1:
        g.edges[n, m]['color'] = POSITIVE_COLOR
    else:
        g.edges[n, m]['color'] = NEGATIVE_COLOR


def build_graph(frac_positives=0.5):
    g = nx.complete_graph(NUM_NODES)

    sn.reset_node_colors(g)

    for n, m in g.edges:
        if random() < frac_positives:
            g.edges[n, m]['signal'] = 1
        else:
            g.edges[n, m]['signal'] = -1

        set_edge_color(g, n, m)

    sn.reset_positions(g)

    return g

# %% [markdown]
# Passo da simulação:

# %%
def invert(g, n, m):
    g.edges[n, m]['signal'] *= -1

    set_edge_color(g, n, m)


def update(g, mec2_weight=1, mec3_weight=1, mec5_weight=1):
    # Inicializa as pressões.

    for n, m in g.edges():
        g.edges[n, m]['pressure'] = 0

    # Para cada tríade.

    for t in combinations(g.nodes, 3):
        # Lista todas as arestas da tríade.
        edges = [(t[0], t[1]), (t[0], t[2]), (t[1], t[2])]

        # Conta quantas arestas são positivas.
        num_positives = sum(g.edges[n, m]['signal'] == 1 for n, m in edges)

        # Duas positivas significa tríade instável.
        if num_positives == 2:
            for n, m in edges:
                if g.edges[n, m]['signal'] == -1:
                    g.edges[n, m]['pressure'] += mec2_weight # Mecanismo 2
                else:
                    g.edges[n, m]['pressure'] += mec3_weight # Mecanismo 3

        # Zero positivas também significa tríade instável.
        elif num_positives == 0:
            for n, m in edges:
                g.edges[n, m]['pressure'] += mec5_weight # Mecanismo 5

    # Obtém a maior pressão.
    pressure = max(g.edges[n, m]['pressure'] for n, m in g.edges)

    # Se for positiva, inverte uma aresta que esteja
    # sob essa pressão, escolhida aleatoriamente, e
    # devolve True para indicar que houve mudança.
    if pressure > 0:
        n, m = choice([(n, m) for n, m in g.edges if g.edges[n, m]['pressure'] == pressure])
        invert(g, n, m)
        return True

    # Se for zero, devolvendo False para indicar que
    # não houve mudança, ou seja, a rede estabilizou.
    return False

# %% [markdown]
# Animação da simulação:

# %%
g = build_graph()

sn.reset_positions(g)

frames = []

while update(g):
    sn.update_positions(g, weight='signal')

    frames.append(sn.generate_frame(g))

print('simulação encerrada, gerando animação...')

sn.show_animation(frames)
# Out:
# simulação encerrada, gerando animação...
# <div id="0cf0a7b7-6a68-46f2-859a-474ec4ba3d31" style="height: 526.0px; width: 912.0px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '0cf0a7b7-6a68-46f2-859a-474ec4ba3d31',
#             [{"mode": "lines", "y": [1.0, 0.6756245819287159, null], "x": [0.6247938804587602, 0.11089819758620242, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.5827331440757147, null], "x": [0.6247938804587602, 0.20279390522132007, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.825751147850284, null], "x": [0.6247938804587602, 0.5435944982008251, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.8251362551078808, null], "x": [0.6247938804587602, 1.0, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.967016023383679, null], "x": [0.6247938804587602, 0.09883184474640777, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.17967002344215105, null], "x": [0.6247938804587602, 0.0, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.3721667125269367, null], "x": [0.6247938804587602, 0.9660040625746208, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.4793548143680442, null], "x": [0.6247938804587602, 0.7131003476210211, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.5173685091612449, null], "x": [0.6247938804587602, 0.04172337308559186, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.0, null], "x": [0.6247938804587602, 0.6090782468906575, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.9769239735366325, null], "x": [0.6247938804587602, 0.29222040622308243, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.17163077146058808, null], "x": [0.6247938804587602, 0.9379982130468699, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.41848100282944073, null], "x": [0.6247938804587602, 0.6274659513878698, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [1.0, 0.07779449377770353, null], "x": [0.6247938804587602, 0.24534358984362054, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.5827331440757147, null], "x": [0.11089819758620242, 0.20279390522132007, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.825751147850284, null], "x": [0.11089819758620242, 0.5435944982008251, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.8251362551078808, null], "x": [0.11089819758620242, 1.0, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.967016023383679, null], "x": [0.11089819758620242, 0.09883184474640777, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.17967002344215105, null], "x": [0.11089819758620242, 0.0, null], "hoverinfo": "none", "line": {"color": "rgb(255, 0, 0)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.3721667125269367, null], "x": [0.11089819758620242, 0.9660040625746208, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.4793548143680442, null], "x": [0.11089819758620242, 0.7131003476210211, null], "hoverinfo": "none", "line": {"color": "rgb(0, 0, 255)", "width": 1}}, {"mode": "lines", "y": [0.6756245819287159, 0.5173685091612449, null], "x": [0.11089819758620242, 0.04172337308559186, null], "hoverinfo": "none", "line": {"colo ...

# %% [markdown]
# Avaliação da simulação:

# %%
def number_components(g):
    h = g.copy()

    for n, m in g.edges:
        if g.edges[n, m]['signal'] == -1:
            h.remove_edge(n, m)

    return nx.number_connected_components(h)


print(number_components(g))
# Out:
# 2
